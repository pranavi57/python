# %% [markdown]
# #markdown
# ##markdown
# ###markdown
# ####markdown

# %% [markdown]
# #insert site address
# [site](https://sites.google.com/view/crt-gitam-batch-2)

# %% [markdown]
# #insert image address
# ![site](https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/golden-retriever-royalty-free-image-506756303-1560962726.jpg?crop=0.669xw:1.00xh;0.166xw,0&resize=640:*)

# %% [markdown]
# # python basics:
# python is a beginners language
#
# python is easy to learn

# %% [markdown]
# # creating ordered list
# 1. abs
# 2. hsdf
# 3. welcome

# %% [markdown]
# # creating unordered list
#
# - hello
# - hi
# - welcome

# %% [markdown]
# ## bold and italic text
# **pranavi**
#
# *pranavi*

# %%
#basic hello
print("hello world!!")
# Out:
# hello world!!

# %%
#variable creation
x=10
y=30
x+y
# Out:
# 40

# %% [markdown]
# #rules for variable
# - name should begin with a character
# - no special character allowed except_

# %%
name ="ajay"
age = 20
print("my name is:",name,"age is:",age)
# Out:
# my name is: ajay age is: 20

# %%
name = input("enter name")
age = int(input("enter age"))
print("my name is:",name,"age is:",age)
# Out:
# enter nameajay
# enter age20
# my name is: ajay age is: 20

# %%
x = int(input("enter a number"))
y = int(input("enter a number"))
print("add is:",x+y,"sub is",x-y,"mul is",x*y,"div is",x/y,"mod is ",x%y)
# Out:
# enter a number20
# enter a number30
# add is: 50 sub is -10 mul is 600 div is 0.6666666666666666 mod is  20

# %% [markdown]
# # fundemental datatypes
# - int
# - float
# - complex
# - boolean
# - string

# %%
x = 10
y = 12.32
z = 5+6j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
c = complex(2,5)
print(c)
# Out:
# (2+5j)

# %%
c1 = 3+6j
c2 = 6+7j
print(c1+c2)
print(c1-c2)
print(c1*c2)
# Out:
# (9+13j)
# (-3-1j)
# (-24+57j)

# %%
x = 6
y = 8
x < y
# Out:
# True

# %%
# string
s1 = "abd"
s2 = "dfg"
print(type(s1),type(s2))
# Out:
# <class 'str'> <class 'str'>

# %%
i = 100
print(type(i))
s1 = str(i)
print(type(s1))
f1=float(i)
print(type(f1))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
# length
a = 1234
print(len(str(a)))
# Out:
# 4

# %%
n1 = 100 #single variable assignment
a = b = c =20 #multiple variable assignment of same value
a1,b1,c1 = 1234,234,345
print(n1)
print(a,b,c)
print(a1,b1,c1)
# Out:
# 100
# 20 20 20
# 1234 234 345

# %% [markdown]
# # precedence of the arth operators
# - parenthesis
# - power
# - multiplication
# - addition

# %%
x = 1 + 2 ** 3 /4 + 5
print(x)
# Out:
# 8.0

# %%
x = 1 + 2 ** 3 /4 * 5
print(x)
# Out:
# 11.0

# %% [markdown]
# #operators
# ## arithmetic operators
# - +
# - -
# - *
# - /
# - %
# - **
# - //

# %%
x = 10
y = 5
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x%y)
print(x**y)
print(x//y)
# Out:
# 15
# 5
# 50
# 2.0
# 0
# 100000
# 2

# %% [markdown]
# # relational operator
# - ==,!=,<,>,<=,>=

# %%
x =5
a = x>10
print(a)
b= x<10
print(b)
# Out:
# False
# True

# %% [markdown]
# logical operators
#  - and
#  - or
#  - not

# %%
i = 100
a1 = (i > 15) and (i > 76)
a2 = (i > 567) or (i > 3456)
print(a1)
print(a2)
print(not i)
# Out:
# True
# False
# False

# %% [markdown]
# # membership operator
# - in
# - notin

# %%
str1 = "abc"
print('a' in str1)
print('a' not in str1)
# Out:
# True
# False

# %% [markdown]
# # control flow statements
# - conditional statements
# - looping statements
# ##if - else statement
#  - syntax
#  #### if condition:
#  > statements<br>
# ##### else:
# > statements

# %%
# check given number is even or odd
n =int(input("enter a number"))
if n%2 ==0:
  print("even")
else:
    print("odd")
# Out:
# enter a number13
# odd

# %%
#check given number is perfectly multiple of 3 and 5
n =int(input("enter a number"))
if n%3 ==0 and n%5 ==0:
  print("multiple")
else:
  print("not multiple")
# Out:
# enter a number21
# not multiple

# %%
# check given number is positive,negative or zero
n =int(input("enter "))

# %%
# check input year is leap year or not
